# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import os, math, random, PIL, time

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

from PIL import Image

import torch.nn as nn
import torch
import torchvision
import torch.nn.functional as F
import torchvision.transforms as transforms
import torch.optim as optim

from collections import defaultdict

# %%
def timer_start():
    global t0
    t0 = time.time()
    
def timer_end():   
    print('Time elapsed {:0.1f}s'.format(time.time() - t0))  

def display_grid(data, path, w =10, h =10, columns = 4, rows = 5):
    fig=plt.figure(figsize=(12, 8))
    for i in range(1, columns*rows +1):
        file = data[i]
        file = os.path.join(path, file)
        img = Image.open(file)
        fig.add_subplot(rows, columns, i)
        imshow(img)
    plt.show()
    
def get_best_epcoh(history):
    valid_acc = history['val_acc']
    best_epoch = valid_acc.index(max(valid_acc)) +1
    best_acc =  max(valid_acc)
    print('Best Validation Accuracy Score {:0.5f}, is for epoch {}'.format( best_acc, best_epoch))
    return best_epoch

def plot_results(history):
    tr_acc = history['tr_acc']
    val_acc = history['val_acc']
    tr_loss = history['tr_loss']
    val_loss = history['val_loss']
    epochs = history['epoch']

    plt.figure(figsize = (24, 6))
    plt.subplot(1,2,1)
    plt.plot(epochs, tr_acc, 'b', label = 'Training Accuracy')
    plt.plot(epochs, val_acc, 'r', label = 'Validation Accuracy')
    plt.grid(True)
    plt.legend()
    plt.xlabel('Epoch')  
    
    plt.subplot(1,2,2)
    plt.plot(epochs, tr_loss, 'b', label = 'Training Loss')
    plt.plot(epochs, val_loss, 'r', label = 'Validation Loss')
    plt.grid(True)
    plt.legend()
    plt.xlabel('Epoch')
    plt.show()
    
def set_seed(seed):
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    
def online_mean_and_sd(loader):
    """Compute the mean and sd in an online fashion

        Var[x] = E[X^2] - E^2[X]
    """
    cnt = 0
    fst_moment = torch.empty(3)
    snd_moment = torch.empty(3)

    for images, _ in loader:

        b, c, h, w = images.shape
        nb_pixels = b * h * w
        sum_ = torch.sum(images, dim=[0, 2, 3])
        sum_of_square = torch.sum(images ** 2, dim=[0, 2, 3])
        fst_moment = (cnt * fst_moment + sum_) / (cnt + nb_pixels)
        snd_moment = (cnt * snd_moment + sum_of_square) / (cnt + nb_pixels)

        cnt += nb_pixels

    return fst_moment, torch.sqrt(snd_moment - fst_moment ** 2)

# %% [markdown]
# ## Class Swift

# %%
base_dir = '/kaggle/input/cars-wagonr-swift/data/'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation' )

train_swift = os.listdir(os.path.join(base_dir, 'train/swift') )
val_swift  = os.listdir(os.path.join(base_dir, 'validation/swift') )
test_swift  =  os.listdir(os.path.join(base_dir, 'test/swift') )
print('Instances for Class Swift: Train {}, Validation {} Test {}'.format(len(train_swift), len(val_swift), len(test_swift)))
# Out:
# Instances for Class Swift: Train 1200, Validation 400 Test 400

# %%
#Sanity checks: no overlaping bteween train test and validation sets
val_train = [x for x in val_swift if x in train_swift]
test_train = [x for x in test_swift if x in train_swift]
val_test =  [x for x in test_swift if x in val_swift]
len(val_train), len(test_train), len(val_test)
# Out:
# (0, 0, 0)

# %%
display_grid(data = train_swift, path = os.path.join(base_dir, 'train/swift'), w =10, h =10, columns = 8, rows = 5)

# %% [markdown]
# ## Class Wagonr

# %%
train_wr = os.listdir(os.path.join(base_dir, 'train/wagonr') )
val_wr  = os.listdir(os.path.join(base_dir, 'validation/wagonr') )
test_wr  =  os.listdir(os.path.join(base_dir, 'test/wagonr') )
print('Instances for Class Wagonr: Train {}, Validation {} Test {}'.format(len(train_swift), len(val_swift), len(test_swift)))
# Out:
# Instances for Class Wagonr: Train 1200, Validation 400 Test 400

# %%
#Sanity checks: no overlaping bteween train test and validation sets
val_train = [x for x in val_wr if x in train_wr]
test_train = [x for x in test_wr if x in train_wr]
val_test =  [x for x in test_wr if x in val_wr]
len(val_train), len(test_train), len(val_test)
# Out:
# (0, 0, 0)

# %%
display_grid(data = train_wr, path = os.path.join(base_dir, 'train/wagonr'), w =10, h =10, columns = 8, rows = 5)

# %% [markdown]
# ## Data Preprocessing With Augmentaion

# %% [markdown]
# #### An example of Augmentation Applied

# %%
# https://colab.research.google.com/drive/109vu3F1LTzD1gdVV6cho9fKGx7lzbFll#scrollTo=9NRlYXKQy3Kx
# https://pytorch.org/docs/stable/torchvision/transforms.html
import matplotlib as mpl
mpl.rcParams['axes.grid'] = False
mpl.rcParams['image.interpolation'] = 'nearest'
mpl.rcParams['figure.figsize'] = 15, 25

def show_dataset(dataset, n=6):
  img = np.vstack((np.hstack((np.asarray(dataset[i][0]) for _ in range(n)))
                   for i in range(4)))
  plt.imshow(img)
  plt.axis('off')

transform_train = transforms.Compose( [                                  
                                 transforms.Resize((150,150)), 
#                                  transforms.RandomCrop(size =100),
                                 transforms.RandomHorizontalFlip(),
                                 transforms.RandomRotation(20, resample=PIL.Image.BILINEAR),
                                 transforms.ColorJitter(hue= 0.01, saturation=.01),
                                 transforms.RandomAffine(degrees = 0, translate=(0.2,0.2),  shear= 0.2),
                                  ])

trainset = torchvision.datasets.ImageFolder( root= train_dir ,
                                              transform= transform_train
                                               )

show_dataset(trainset)
# len(trainset)

# %%
# from https://forums.fast.ai/t/normalizing-your-dataset/49799
# Compute the mean and standrad deviation of the training images for each channel. This will be used to normalize the tensors to [-1,1]

transform = transforms.Compose( [                                  
                                 transforms.Resize((150,150)), 
                                 transforms.ToTensor(),
                                  ])

trainset = torchvision.datasets.ImageFolder( root= train_dir ,
                                              transform=transform
                                               )

trainloader = torch.utils.data.DataLoader(trainset, batch_size= 512 ,
                                          shuffle=True, num_workers=1)
mean, std = online_mean_and_sd(trainloader)
print(mean, std)
# Out:
# tensor([0.4508, 0.4365, 0.4216]) tensor([0.2561, 0.2542, 0.2592])

# %%
BATCH_SIZE = 20
# transforms.ToTensor() trasnforms the pixels from [0,255] to [0,1] which is then 
# trasnformed to [-1,1] using Normalize with mean computed mean and std for each of three channels
transform_train = transforms.Compose( [                                  
                                     transforms.Resize((150,150)), 
                                     transforms.Resize((150,150)), 
                                     transforms.RandomHorizontalFlip(),
                                     transforms.RandomRotation(20, resample=PIL.Image.BILINEAR),
                                     transforms.ColorJitter(hue= 0.01, saturation=.01),
                                     transforms.RandomAffine(degrees = 0, translate=(0.2,0.2),  shear= 0.2),
                                     transforms.ToTensor(),
                                     transforms.Normalize(mean, std),
                                  ])



#Validation and test set should not be augumented, hence different transforms
transform_test = transforms.Compose( [                                  
                                 transforms.Resize((150,150)), 
                                 transforms.ToTensor(),
                                 transforms.Normalize(mean, std),
                                  ])
trainset = torchvision.datasets.ImageFolder( root= train_dir ,
                                              transform= transform_train
                                               )


trainloader = torch.utils.data.DataLoader(trainset, batch_size= BATCH_SIZE,
                                          shuffle=True, num_workers=1)


validset = torchvision.datasets.ImageFolder( root= validation_dir ,
                                              transform= transform_test 
                                               )


validloader = torch.utils.data.DataLoader(validset , batch_size= BATCH_SIZE,
                                          shuffle=True, num_workers=1)

print(online_mean_and_sd(trainloader))
# Out:
# (tensor([-0.3978, -0.3840, -0.3514]), tensor([1.1430, 1.1349, 1.1154]))

# %% [markdown]
# ## Build CNN model

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(in_channels= 3, out_channels=32, kernel_size= 3)
        self.pool = nn.MaxPool2d(kernel_size=2, stride= 2)
        
        self.conv2 =  nn.Conv2d(in_channels= 32, out_channels= 64, kernel_size= 3)
        self.conv3 =  nn.Conv2d(in_channels= 64, out_channels= 128, kernel_size= 3)
        self.conv4 =  nn.Conv2d(in_channels= 128, out_channels= 128, kernel_size= 3)
    
#       128 * 128 * 7 is the output of the last max pool layer
        self.fc1 = nn.Linear(128 * 7 * 7, 512)
        self.fc2 = nn.Linear(512, 2)       

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = self.pool(F.relu(self.conv4(x)))
        
        #this is similar to flatten in keras but keras is smart to figure out dimensions by iteself.
        x = x.view(-1, 128 * 7 * 7)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)       
        return x

# %% [markdown]
# ## Train Model

# %% [markdown]
# ### Custom Train and Test Function

# %%
def train(model, epoch, train_loader, optimizer, criterion) :   
    model.train()
    epoch_loss = correct = 0
    for i, data in enumerate(train_loader, 0):
        # Load images with gradient accumulation capabilities
        inputs, labels = data[0].to(device), data[1].to(device)
        # Clear gradients w.r.t. parameters       
        optimizer.zero_grad()

        # Forward pass to get output/logits
        outputs = model(inputs)

         # Calculate Loss: softmax --> cross entropy loss
        loss =  criterion(outputs, labels)
        
        # Get predictions from the maximum value
        _, predicted = torch.max(outputs.data, 1)           

        # Total correct predictions 
        correct += (predicted == labels).sum().item()  

        # Getting gradients w.r.t. parameters
        loss.backward()

         # Updating parameters
        optimizer.step() 
        
        #Multiple loss by number of batch as loss is averaged per batch
        epoch_loss += outputs.shape[0] * loss.item()
        
    accuracy = correct / len(train_loader.dataset)
    epoch_loss = epoch_loss / len(train_loader.dataset)
    return epoch_loss, accuracy


def test(model, epoch, test_loader, optimizer, criterion):
    model.eval()
    epoch_loss = correct = 0

    with torch.no_grad():
        #Iterate through test dataset after every epoch
        for i, data in enumerate(test_loader, 0):
            images, labels = data[0].to(device), data[1].to(device)
            # Forward pass only to get logits/output
            outputs = model(images)

            # Calculate Validation Loss
            loss =    criterion(outputs, labels)

            # Get predictions from the maximum value
            _, predicted = torch.max(outputs.data, 1)           

            # Total correct predictions 
            correct += (predicted == labels).sum().item()  

             #Multiple loss by number of batch as loss is averaged per batch so that we get
            #total loss over an epoch and then divide by number of samples to get loss per epcoh
            epoch_loss += outputs.shape[0] * loss.item()

    
    accuracy = correct / len(test_loader.dataset)
    epoch_loss = epoch_loss / len(test_loader.dataset)
  
    return epoch_loss, accuracy

# %% [markdown]
# ### Set Loss Function and Optimizers

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = Net()
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.RMSprop(model.parameters(), lr=0.0001)
print('Divice: ',device)
model
# Out:
# Divice:  cuda:0
# Net(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (conv4): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=6272, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=2, bias=True)
# )

# %% [markdown]
# ### Train and Validate

# %%
# %%time
EPOCHS = 100

#To get reprodicible results but not working at mommnet
# set_seed(42)

train_list  = os.listdir(os.path.join(base_dir, 'train/swift') ) + os.listdir(os.path.join(base_dir, 'train/wagonr') )
num_batches = math.ceil(len(train_list) / BATCH_SIZE)

print('Number of Training samples {}, Batch Size {}, Num Batch {}'.format( len(train_list), BATCH_SIZE, num_batches ))

history = defaultdict(list)


# Get Keras like outputs for Training and validation by using custom train and test functions.
for epoch in range( EPOCHS):  
    timer_start()
    print('[Epoch {} of {}]'.format(epoch +1, EPOCHS),end = ' ')
    tr_loss, tr_acc = train(model, epoch, trainloader, optimizer, criterion)

    val_loss, val_acc = test(model, epoch, validloader, optimizer, criterion)  
    timer_end()
    print('tr_loss: {:0.4f},tr_acc {:0.4f}| val_loss {:0.4f}, val_acc {:0.4f}'.format(tr_loss, tr_acc , val_loss, val_acc))
    history['epoch'].append(epoch+1)
    history['tr_loss'].append(round(tr_loss,5))
    history['tr_acc'].append(round(tr_acc,5))
    history['val_loss'].append(round(val_loss,5))
    history['val_acc'].append(round(val_acc,5))
# Out:
# Number of Training samples 2400, Batch Size 20, Num Batch 120
# [Epoch 1 of 100] Time elapsed 18.6s
# tr_loss: 0.6895,tr_acc 0.5279| val_loss 0.6708, val_acc 0.5988
# [Epoch 2 of 100] Time elapsed 18.4s
# tr_loss: 0.6652,tr_acc 0.5950| val_loss 0.6660, val_acc 0.5887
# [Epoch 3 of 100] Time elapsed 18.8s
# tr_loss: 0.6300,tr_acc 0.6546| val_loss 0.5598, val_acc 0.7087
# [Epoch 4 of 100] Time elapsed 18.2s
# tr_loss: 0.5771,tr_acc 0.7067| val_loss 0.4877, val_acc 0.7788
# [Epoch 5 of 100] Time elapsed 18.2s
# tr_loss: 0.5205,tr_acc 0.7354| val_loss 0.4171, val_acc 0.8063
# [Epoch 6 of 100] Time elapsed 18.4s
# tr_loss: 0.4763,tr_acc 0.7638| val_loss 0.4943, val_acc 0.7488
# [Epoch 7 of 100] Time elapsed 18.8s
# tr_loss: 0.4569,tr_acc 0.7796| val_loss 0.3800, val_acc 0.8300
# [Epoch 8 of 100] Time elapsed 18.8s
# tr_loss: 0.4267,tr_acc 0.7954| val_loss 0.3564, val_acc 0.8425
# [Epoch 9 of 100] Time elapsed 19.4s
# tr_loss: 0.4159,tr_acc 0.8029| val_loss 0.3763, val_acc 0.8300
# [Epoch 10 of 100] Time elapsed 18.1s
# tr_loss: 0.3847,tr_acc 0.8267| val_loss 0.3444, val_acc 0.8512
# [Epoch 11 of 100] Time elapsed 18.9s
# tr_loss: 0.3708,tr_acc 0.8337| val_loss 0.3261, val_acc 0.8638
# [Epoch 12 of 100] Time elapsed 18.6s
# tr_loss: 0.3500,tr_acc 0.8500| val_loss 0.3562, val_acc 0.8413
# [Epoch 13 of 100] Time elapsed 18.2s
# tr_loss: 0.3540,tr_acc 0.8400| val_loss 0.3138, val_acc 0.8725
# [Epoch 14 of 100] Time elapsed 18.4s
# tr_loss: 0.3316,tr_acc 0.8475| val_loss 0.3023, val_acc 0.8700
# [Epoch 15 of 100] Time elapsed 18.4s
# tr_loss: 0.3290,tr_acc 0.8471| val_loss 0.3112, val_acc 0.8725
# [Epoch 16 of 100] Time elapsed 18.7s
# tr_loss: 0.3093,tr_acc 0.8629| val_loss 0.2803, val_acc 0.8900
# [Epoch 17 of 100] Time elapsed 18.7s
# tr_loss: 0.2949,tr_acc 0.8700| val_loss 0.3405, val_acc 0.8488
# [Epoch 18 of 100] Time elapsed 18.4s
# tr_loss: 0.2865,tr_acc 0.8775| val_loss 0.2658, val_acc 0.9075
# [Epoch 19 of 100] Time elapsed 18.3s
# tr_loss: 0.2766,tr_acc 0.8733| val_loss 0.2928, val_acc 0.8838
# [Epoch 20 of 100] Time elapsed 18.7s
# tr_loss: 0.2690,tr_acc 0.8888| val_loss 0.2364, val_acc 0.9100
# [Epoch 21 of 100] Time elapsed 18.5s
# tr_loss: 0.2571,tr_acc 0.8842| val_loss 0.2343, val_acc 0.9163
# [Epoch 22 of 100] Time elapsed 18.3s
# tr_loss: 0.2493,tr_acc 0.8921| val_loss 0.2616, val_acc 0.9075
# [Epoch 23 of 100] Time elapsed 18.6s
# tr_loss: 0.2384,tr_acc 0.9038| val_loss 0.2411, val_acc 0.9038
# [Epoch 24 of 100] Time elapsed 18.7s
# tr_loss: 0.2411,tr_acc 0.8921| val_loss 0.2017, val_acc 0.9113
# [Epoch 25 of 100] Time elapsed 19.1s
# tr_loss: 0.2251,tr_acc 0.9042| val_loss 0.2270, val_acc 0.9062
# [Epoch 26 of 100] Time elapsed 18.1s
# tr_loss: 0.2335,tr_acc 0.8988| val_loss 0.2135, val_acc 0.9075
# [Epoch 27 of 100] Time elapsed 18.3s
# tr_loss: 0.2131,tr_acc 0.9125| val_loss 0.2340, val_acc 0.9100
# [Epoch 28 of 100] Time elapsed 18.7s
# tr_loss: 0.2069,tr_acc 0.9171| val_loss 0.2327, val_acc 0.8912
# [Epoch 29 of 100] Time elapsed 18.5s
# tr_loss: 0.1969,tr_acc 0.9171| val_loss 0.1872, val_acc 0.9350
# [Epoch 30 of 100] Time elapsed 18.3s
# tr_loss: 0.2009,tr_acc 0.9142| val_loss 0.1926, val_acc 0.9275
# [Epoch 31 of 100] Time elapsed 18.6s
# tr_loss: 0.1857,tr_acc 0.9217| val_loss 0.1841, val_acc 0.9237
# [Epoch 32 of 100] Time elapsed 18.6s
# tr_loss: 0.1774,tr_acc 0.9279| val_loss 0.1863, val_acc 0.9225
# [Epoch 33 of 100] Time elapsed 18.3s
# tr_loss: 0.1886,tr_acc 0.9213| val_loss 0.2235, val_acc 0.9200
# [Epoch 34 of 100] Time elapsed 18.3s
# tr_loss: 0.1761,tr_acc 0.9279| val_loss 0.1739, val_acc 0.9313
# [Epoch 35 of 100] Time elapsed 18.2s
# tr_loss: 0.1603,tr_acc 0.9358| val_loss 0.1550, val_acc 0.9337
# [Epoch 36 of 100] Time elapsed 18.6s
# tr_loss: 0.1521,tr_acc 0.9363| val_loss 0.1648, val_acc 0.9250
# [Epoch 37 of 100] Time elapsed 18.6s
# tr_loss: 0.1619,tr_acc 0.9396| val_loss 0.1787, val_acc 0.9300
# [Epoch 38 of 100] Time elapsed 18.3s
# tr_loss: 0.1387,tr_acc 0.9429| val_loss 0.1491, val_acc 0.9450
# [Epoch 39 of 100] Time elapsed 18.6s
# tr_loss: 0.1447,tr_acc 0.9425| val_loss 0.1964, val_acc 0.9275
# [Epoch 40 of 100] Time elapsed 18.7s
# tr_loss: 0.1254,tr_acc 0.9475| val_loss 0.1736, val_acc 0.9450
# [Epoch 41 of 100] Time elapsed 18.2s
# tr_loss: 0.1281,tr_acc 0.9508| val_loss 0.1506, val_acc 0.9413
# [Epoch 42 of 100] Time elapsed 19.0s
# tr_loss: 0.1493,tr_acc 0.9417| val_loss 0.1754, val_acc 0.9237
# [Epoch 43 of 100] Time elapsed 18.5s
# tr_loss: 0.1240,tr_acc 0.9546| val_loss 0.1722, val_acc 0.9250
# [Epoch 44 of 100] Time elapsed 18.6s
# tr_loss: 0.1341,tr_acc 0.9483| val_loss 0.1534, val_acc 0.9387
# [Epoch 45 of 100] Time elapsed 18.1s
# tr_loss: 0.1270,tr_acc 0.9492| val_loss 0.1994, val_acc 0.9337
# [Epoch 46 of 100] Time elapsed 18.4s
# tr_loss: 0.1117,tr_acc 0.9567| val_loss 0.1517, val_acc 0.9300
# [Epoch 47 of 100] Time elapsed 18.5s
# tr_loss: 0.1199,tr_acc 0.9496| val_loss 0.1487, val_acc 0.9413
# [Epoch 48 of 100] Time elapsed 18.1s
# tr_loss: 0.1121,tr_acc 0.9600| val_loss 0.1335, val_acc 0.9437
# [Epoch 49 of 100] Time elapsed 18.2s
# tr_loss: 0.1201,tr_acc 0.9533| val_loss 0.1546, val_acc 0.9350
# [Epoch 50 of 100] Time elapsed 18.1s
# tr_loss: 0.1113,tr_acc 0.9579| val_loss 0.1402, val_acc 0.9387
# [Epoch 51 of 100] Time elapsed 18.3s
# tr_loss: 0.1217,tr_acc 0.9537| val_loss 0.1245, val_acc 0.9475
# [Epoch 52 of 100] Time elapsed 17.9s
# tr_loss: 0.0976,tr_acc 0.9646| val_loss 0.1208, val_acc 0.9463
# [Epoch 53 of 100] Time elapsed 18.6s
# tr_loss: 0.1000,tr_acc 0.9558| val_loss 0.1410, val_acc 0.9363
# [Epoch 54 of 100] Time elapsed 18.2s
# tr_loss: 0.0987,tr_acc 0.9663| val_loss 0.1637, val_acc 0.9363
# [Epoch 55 of 100] Time elapsed 18.3s
# tr_loss: 0.0884,tr_acc 0.9667| val_loss 0.1853, val_acc 0.9400
# [Epoch 56 of 100] Time elapsed 18.4s
# tr_loss: 0.0914,tr_acc 0.9663| val_loss 0.1662, val_acc 0.9375
# [Epoch 57 of 100] Time elapsed 18.3s
# tr_loss: 0.0856,tr_acc 0.9688| val_loss 0.1880, val_acc 0.9350
# [Epoch 58 of 100] Time elapsed 18.8s
# tr_loss: 0.0826,tr_acc 0.9688| val_loss 0.1485, val_acc 0.9425
# [Epoch 59 of 100] Time elapsed 18.4s
# tr_loss: 0.0885,tr_acc 0.9688| val_loss 0.1978, val_acc 0.9313
# [Epoch 60 of 100] Time elapsed 18.4s
# tr_loss: 0.0900,tr_acc 0.9696| val_loss 0.1338, val_acc 0.9413
# [Epoch 61 of 100] Time elapsed 18.4s
# tr_loss: 0.0781,tr_acc 0.9704| val_loss 0.1401, val_acc 0.9525
# [Epoch 62 of 100] Time elapsed 18.2s
# tr_loss: 0.0754,tr_acc 0.9704| val_loss 0.1361, val_acc 0.9463
# [Epoch 63 of 100] Time elapsed 18.5s
# tr_loss: 0.0777,tr_acc 0.9663| val_loss 0.1550, val_acc 0.9450
# [Epoch 64 of 100] Time elapsed 18.3s
# tr_loss: 0.0897,tr_acc 0.9675| val_loss 0.1320, val_acc 0.9525
# [Epoch 65 of 100] Time elapsed 18.4s
# tr_loss: 0.0631,tr_acc 0.9725| val_loss 0.1748, val_acc 0.9337
# [Epoch 66 of 100] Time elapsed 18.4s
# tr_loss: 0.0741,tr_acc 0.9717| val_loss 0.1447, val_acc 0.9450
# [Epoch 67 of 100] Time elapsed 18.2s
# tr_loss: 0.0709,tr_acc 0.9717| val_loss 0.1445, val_acc 0.9437
# [Epoch 68 of 100] Time elapsed 18.7s
# tr_loss: 0.0680,tr_acc 0.9771| val_loss 0.1221, val_acc 0.9513
# [Epoch 69 of 100] Time elapsed 18.3s
# tr_loss: 0.0647,tr_acc 0.9750| val_loss 0.2842, val_acc 0.9050
# [Epoch 70 of 100] Time elapsed 18.5s
# tr_loss: 0.0754,tr_acc 0.9717| val_loss 0.1260, val_acc 0.9425
# [Epoch 71 of 100] Time elapsed 18.1s
# tr_loss: 0.0522,tr_acc 0.9821| val_loss 0.1946, val_acc 0.9175
# [Epoch 72 of 100] Time elapsed 18.5s
# tr_loss: 0.0839,tr_acc 0.9679| val_loss 0.1020, val_acc 0.9613
# [Epoch 73 of 100] Time elapsed 18.6s
# tr_loss: 0.0579,tr_acc 0.9762| val_loss 0.2193, val_acc 0.9237
# [Epoch 74 of 100] Time elapsed 18.1s
# tr_loss: 0.0607,tr_acc 0.9771| val_loss 0.1328, val_acc 0.9463
# [Epoch 75 of 100] Time elapsed 19.1s
# tr_loss: 0.0530,tr_acc 0.9796| val_loss 0.1930, val_acc 0.9413
# [Epoch 76 of 100] Time elapsed 18.6s
# tr_loss: 0.0640,tr_acc 0.9771| val_loss 0.2601, val_acc 0.9137
# [Epoch 77 of 100] Time elapsed 18.9s
# tr_loss: 0.0500,tr_acc 0.9825| val_loss 0.1257, val_acc 0.9487
# [Epoch 78 of 100] Time elapsed 18.0s
# tr_loss: 0.0628,tr_acc 0.9775| val_loss 0.1104, val_acc 0.9550
# [Epoch 79 of 100] Time elapsed 18.1s
# tr_loss: 0.0498,tr_acc 0.9821| val_loss 0.1253, val_acc 0.9450
# [Epoch 80 of 100] Time elapsed 18.8s
# tr_loss: 0.0563,tr_acc 0.9762| val_loss 0.1779, val_acc 0.9413
# [Epoch 81 of 100] Time elapsed 18.5s
# tr_loss: 0.0532,tr_acc 0.9829| val_loss 0.1243, val_acc 0.9575
# [Epoch 82 of 100] Time elapsed 18.6s
# tr_loss: 0.0402,tr_acc 0.9871| val_loss 0.1674, val_acc 0.9387
# [Epoch 83 of 100] Time elapsed 18.5s
# tr_loss: 0.0556,tr_acc 0.9825| val_loss 0.1272, val_acc 0.9463
# [Epoch 84 of 100] Time elapsed 18.2s
# tr_loss: 0.0461,tr_acc 0.9838| val_loss 0.2166, val_acc 0.9425
# [Epoch 85 of 100] Time elapsed 18.7s
# tr_loss: 0.0525,tr_acc 0.9788| val_loss 0.1555, val_acc 0.9537
# [Epoch 86 of 100] Time elapsed 18.2s
# tr_loss: 0.0510,tr_acc 0.9792| val_loss 0.1148, val_acc 0.9650
# [Epoch 87 of 100] Time elapsed 18.6s
# tr_loss: 0.0392,tr_acc 0.9871| val_loss 0.1313, val_acc 0.9537
# [Epoch 88 of 100] Time elapsed 18.3s
# tr_loss: 0.0462,tr_acc 0.9821| val_loss 0.1346, val_acc 0.9625
# [Epoch 89 of 100] Time elapsed 18.5s
# tr_loss: 0.0519,tr_acc 0.9788| val_loss 0.1623, val_acc 0.9463
# [Epoch 90 of 100] Time elapsed 18.7s
# tr_loss: 0.0380,tr_acc 0.9854| val_loss 0.2078, val_acc 0.9537
# [Epoch 91 of 100] Time elapsed 19.0s
# tr_loss: 0.0676,tr_acc 0.9771| val_loss 0.1365, val_acc 0.9537
# [Epoch 92 of 100] Time elapsed 18.7s
# tr_loss: 0.0325,tr_acc 0.9883| val_loss 0.1753, val_acc 0.9500
# [Epoch 93 of 100] Time elapsed 18.4s
# tr_loss: 0.0499,tr_acc 0.9829| val_loss 0.2520, val_acc 0.9337
# [Epoch 94 of 100] Time elapsed 18.3s
# tr_loss: 0.0563,tr_acc 0.9800| val_loss 0.1345, val_acc 0.9550
# [Epoch 95 of 100] Time elapsed 18.6s
# tr_loss: 0.0338,tr_acc 0.9883| val_loss 0.1325, val_acc 0.9575
# [Epoch 96 of 100] Time elapsed 18.1s
# tr_loss: 0.0381,tr_acc 0.9846| val_loss 0.1635, val_acc 0.9463
# [Epoch 97 of 100] Time elapsed 18.6s
# tr_loss: 0.0384,tr_acc 0.9858| val_loss 0.0940, val_acc 0.9613
# [Epoch 98 of 100] Time elapsed 18.2s
# tr_loss: 0.0389,tr_acc 0.9883| val_loss 0.3668, val_acc 0.9137
# [Epoch 99 of 100] Time elapsed 18.4s
# tr_loss: 0.0515,tr_acc 0.9800| val_loss 0.1246, val_acc 0.9637
# [Epoch 100 of 100] Time elapsed 18.2s
# tr_loss: 0.0439,tr_acc 0.9829| val_loss 0.2380, val_acc 0.9387
# CPU times: user 1min 52s, sys: 1min 54s, total: 3min 46s
# Wall time: 30min 46s

# %% [markdown]
# ## Plot Training vs Validation results[](http://)

# %%
plot_results(history)
best_epoch = get_best_epcoh(history)
# Out:
# Best Validation Accuracy Score 0.96500, is for epoch 86
