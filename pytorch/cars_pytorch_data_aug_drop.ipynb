# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import os, math, random, PIL, time

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

from PIL import Image

import torch.nn as nn
import torch
import torchvision
import torch.nn.functional as F
import torchvision.transforms as transforms
import torch.optim as optim

from collections import defaultdict

# %%
def timer_start():
    global t0
    t0 = time.time()
    
def timer_end():   
    print('Time elapsed {:0.1f}s'.format(time.time() - t0))  

def display_grid(data, path, w =10, h =10, columns = 4, rows = 5):
    fig=plt.figure(figsize=(12, 8))
    for i in range(1, columns*rows +1):
        file = data[i]
        file = os.path.join(path, file)
        img = Image.open(file)
        fig.add_subplot(rows, columns, i)
        imshow(img)
    plt.show()
    
def get_best_epcoh(history):
    valid_acc = history['val_acc']
    best_epoch = valid_acc.index(max(valid_acc)) +1
    best_acc =  max(valid_acc)
    print('Best Validation Accuracy Score {:0.5f}, is for epoch {}'.format( best_acc, best_epoch))
    return best_epoch

def plot_results(history):
    tr_acc = history['tr_acc']
    val_acc = history['val_acc']
    tr_loss = history['tr_loss']
    val_loss = history['val_loss']
    epochs = history['epoch']

    plt.figure(figsize = (24, 6))
    plt.subplot(1,2,1)
    plt.plot(epochs, tr_acc, 'b', label = 'Training Accuracy')
    plt.plot(epochs, val_acc, 'r', label = 'Validation Accuracy')
    plt.grid(True)
    plt.legend()
    plt.xlabel('Epoch')  
    
    plt.subplot(1,2,2)
    plt.plot(epochs, tr_loss, 'b', label = 'Training Loss')
    plt.plot(epochs, val_loss, 'r', label = 'Validation Loss')
    plt.grid(True)
    plt.legend()
    plt.xlabel('Epoch')
    plt.show()
    
def set_seed(seed):
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    
def online_mean_and_sd(loader):
    """Compute the mean and sd in an online fashion

        Var[x] = E[X^2] - E^2[X]
    """
    cnt = 0
    fst_moment = torch.empty(3)
    snd_moment = torch.empty(3)

    for images, _ in loader:

        b, c, h, w = images.shape
        nb_pixels = b * h * w
        sum_ = torch.sum(images, dim=[0, 2, 3])
        sum_of_square = torch.sum(images ** 2, dim=[0, 2, 3])
        fst_moment = (cnt * fst_moment + sum_) / (cnt + nb_pixels)
        snd_moment = (cnt * snd_moment + sum_of_square) / (cnt + nb_pixels)

        cnt += nb_pixels

    return fst_moment, torch.sqrt(snd_moment - fst_moment ** 2)

# %% [markdown]
# ## Class Swift

# %%
base_dir = '/kaggle/input/cars-wagonr-swift/data/'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation' )

train_swift = os.listdir(os.path.join(base_dir, 'train/swift') )
val_swift  = os.listdir(os.path.join(base_dir, 'validation/swift') )
test_swift  =  os.listdir(os.path.join(base_dir, 'test/swift') )
print('Instances for Class Swift: Train {}, Validation {} Test {}'.format(len(train_swift), len(val_swift), len(test_swift)))
# Out:
# Instances for Class Swift: Train 1200, Validation 400 Test 400

# %%
#Sanity checks: no overlaping bteween train test and validation sets
val_train = [x for x in val_swift if x in train_swift]
test_train = [x for x in test_swift if x in train_swift]
val_test =  [x for x in test_swift if x in val_swift]
len(val_train), len(test_train), len(val_test)
# Out:
# (0, 0, 0)

# %%
display_grid(data = train_swift, path = os.path.join(base_dir, 'train/swift'), w =10, h =10, columns = 8, rows = 5)

# %% [markdown]
# ## Class Wagonr

# %%
train_wr = os.listdir(os.path.join(base_dir, 'train/wagonr') )
val_wr  = os.listdir(os.path.join(base_dir, 'validation/wagonr') )
test_wr  =  os.listdir(os.path.join(base_dir, 'test/wagonr') )
print('Instances for Class Wagonr: Train {}, Validation {} Test {}'.format(len(train_swift), len(val_swift), len(test_swift)))
# Out:
# Instances for Class Wagonr: Train 1200, Validation 400 Test 400

# %%
#Sanity checks: no overlaping bteween train test and validation sets
val_train = [x for x in val_wr if x in train_wr]
test_train = [x for x in test_wr if x in train_wr]
val_test =  [x for x in test_wr if x in val_wr]
len(val_train), len(test_train), len(val_test)
# Out:
# (0, 0, 0)

# %%
display_grid(data = train_wr, path = os.path.join(base_dir, 'train/wagonr'), w =10, h =10, columns = 8, rows = 5)

# %% [markdown]
# ## Data Preprocessing With Augmentaion

# %% [markdown]
# #### An example of Augmentation Applied

# %%
# https://colab.research.google.com/drive/109vu3F1LTzD1gdVV6cho9fKGx7lzbFll#scrollTo=9NRlYXKQy3Kx
# https://pytorch.org/docs/stable/torchvision/transforms.html
import matplotlib as mpl
mpl.rcParams['axes.grid'] = False
mpl.rcParams['image.interpolation'] = 'nearest'
mpl.rcParams['figure.figsize'] = 15, 25

def show_dataset(dataset, n=6):
  img = np.vstack((np.hstack((np.asarray(dataset[i][0]) for _ in range(n)))
                   for i in range(4)))
  plt.imshow(img)
  plt.axis('off')

transform_train = transforms.Compose( [                                  
                                 transforms.Resize((150,150)), 
#                                  transforms.RandomCrop(size =100),
                                 transforms.RandomHorizontalFlip(),
                                 transforms.RandomRotation(20, resample=PIL.Image.BILINEAR),
                                 transforms.ColorJitter(hue= 0.01, saturation=.01),
                                 transforms.RandomAffine(degrees = 0, translate=(0.2,0.2),  shear= 0.2),
                                  ])

trainset = torchvision.datasets.ImageFolder( root= train_dir ,
                                              transform= transform_train
                                               )

show_dataset(trainset)
# len(trainset)

# %%
# from https://forums.fast.ai/t/normalizing-your-dataset/49799
# Compute the mean and standrad deviation of the training images for each channel. This will be used to normalize the tensors to [-1,1]

transform = transforms.Compose( [                                  
                                 transforms.Resize((150,150)), 
                                 transforms.ToTensor(),
                                  ])

trainset = torchvision.datasets.ImageFolder( root= train_dir ,
                                              transform=transform
                                               )

trainloader = torch.utils.data.DataLoader(trainset, batch_size= 512 ,
                                          shuffle=True, num_workers=1)
mean, std = online_mean_and_sd(trainloader)
print(mean, std)
# Out:
# tensor([0.4508, 0.4365, 0.4216]) tensor([0.2561, 0.2542, 0.2592])

# %%
BATCH_SIZE = 20
# transforms.ToTensor() trasnforms the pixels from [0,255] to [0,1] which is then 
# trasnformed to [-1,1] using Normalize with mean computed mean and std for each of three channels
transform_train = transforms.Compose( [                                  
                                     transforms.Resize((150,150)), 
                                     transforms.Resize((150,150)), 
                                     transforms.RandomHorizontalFlip(),
                                     transforms.RandomRotation(20, resample=PIL.Image.BILINEAR),
                                     transforms.ColorJitter(hue= 0.01, saturation=.01),
                                     transforms.RandomAffine(degrees = 0, translate=(0.2,0.2),  shear= 0.2),
                                     transforms.ToTensor(),
                                     transforms.Normalize(mean, std),
                                  ])



#Validation and test set should not be augumented, hence different transforms
transform_test = transforms.Compose( [                                  
                                 transforms.Resize((150,150)), 
                                 transforms.ToTensor(),
                                 transforms.Normalize(mean, std),
                                  ])
trainset = torchvision.datasets.ImageFolder( root= train_dir ,
                                              transform= transform_train
                                               )


trainloader = torch.utils.data.DataLoader(trainset, batch_size= BATCH_SIZE,
                                          shuffle=True, num_workers=1)


validset = torchvision.datasets.ImageFolder( root= validation_dir ,
                                              transform= transform_test 
                                               )


validloader = torch.utils.data.DataLoader(validset , batch_size= BATCH_SIZE,
                                          shuffle=True, num_workers=1)

print(online_mean_and_sd(trainloader))
# Out:
# (tensor([-0.3941, -0.3803, -0.3480]), tensor([1.1424, 1.1348, 1.1155]))

# %% [markdown]
# ## Build CNN model

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(in_channels= 3, out_channels=32, kernel_size= 3)
        self.pool = nn.MaxPool2d(kernel_size=2, stride= 2)
        
        self.conv2 =  nn.Conv2d(in_channels= 32, out_channels= 64, kernel_size= 3)
        self.conv3 =  nn.Conv2d(in_channels= 64, out_channels= 128, kernel_size= 3)
        self.conv4 =  nn.Conv2d(in_channels= 128, out_channels= 128, kernel_size= 3)
    
#       128 * 128 * 7 is the output of the last max pool layer
        self.fc1 = nn.Linear(128 * 7 * 7, 512)
        self.fc2 = nn.Linear(512, 2)
        self.dropout = nn.Dropout(p=0.5)
       

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = self.pool(F.relu(self.conv4(x)))
        
        #this is similar to flatten in keras but keras is smart to figure out dimensions by iteself.
        x = x.view(-1, 128 * 7 * 7)   
        x = self.dropout(x)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
       
        return x

# %% [markdown]
# ## Train Model

# %% [markdown]
# ### Custom Train and Test Function

# %%
def train(model, epoch, train_loader, optimizer, criterion) :   
    model.train()
    epoch_loss = correct = 0
    for i, data in enumerate(train_loader, 0):
        # Load images with gradient accumulation capabilities
        inputs, labels = data[0].to(device), data[1].to(device)
        # Clear gradients w.r.t. parameters       
        optimizer.zero_grad()

        # Forward pass to get output/logits
        outputs = model(inputs)

         # Calculate Loss: softmax --> cross entropy loss
        loss =  criterion(outputs, labels)
        
        # Get predictions from the maximum value
        _, predicted = torch.max(outputs.data, 1)           

        # Total correct predictions 
        correct += (predicted == labels).sum().item()  

        # Getting gradients w.r.t. parameters
        loss.backward()

         # Updating parameters
        optimizer.step() 
        
        #Multiple loss by number of batch as loss is averaged per batch
        epoch_loss += outputs.shape[0] * loss.item()
        
    accuracy = correct / len(train_loader.dataset)
    epoch_loss = epoch_loss / len(train_loader.dataset)
    return epoch_loss, accuracy


def test(model, epoch, test_loader, optimizer, criterion):
    model.eval()
    epoch_loss = correct = 0

    with torch.no_grad():
        #Iterate through test dataset after every epoch
        for i, data in enumerate(test_loader, 0):
            images, labels = data[0].to(device), data[1].to(device)
            # Forward pass only to get logits/output
            outputs = model(images)

            # Calculate Validation Loss
            loss =    criterion(outputs, labels)

            # Get predictions from the maximum value
            _, predicted = torch.max(outputs.data, 1)           

            # Total correct predictions 
            correct += (predicted == labels).sum().item()  

             #Multiple loss by number of batch as loss is averaged per batch so that we get
            #total loss over an epoch and then divide by number of samples to get loss per epcoh
            epoch_loss += outputs.shape[0] * loss.item()

    
    accuracy = correct / len(test_loader.dataset)
    epoch_loss = epoch_loss / len(test_loader.dataset)
  
    return epoch_loss, accuracy

# %% [markdown]
# ### Set Loss Function and Optimizers

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = Net()
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.RMSprop(model.parameters(), lr=0.0001)
print('Divice: ',device)
model
# Out:
# Divice:  cuda:0
# Net(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (conv4): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=6272, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=2, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %% [markdown]
# ### Train and Validate

# %%
# %%time
EPOCHS = 200

#To get reprodicible results but not working at mommnet
# set_seed(42)

train_list  = os.listdir(os.path.join(base_dir, 'train/swift') ) + os.listdir(os.path.join(base_dir, 'train/wagonr') )
num_batches = math.ceil(len(train_list) / BATCH_SIZE)

print('Number of Training samples {}, Batch Size {}, Num Batch {}'.format( len(train_list), BATCH_SIZE, num_batches ))

history = defaultdict(list)


# Get Keras like outputs for Training and validation by using custom train and test functions.
for epoch in range( EPOCHS):  
    timer_start()
    print('[Epoch {} of {}]'.format(epoch +1, EPOCHS),end = ' ')
    tr_loss, tr_acc = train(model, epoch, trainloader, optimizer, criterion)

    val_loss, val_acc = test(model, epoch, validloader, optimizer, criterion)  
    timer_end()
    print('tr_loss: {:0.4f},tr_acc {:0.4f}| val_loss {:0.4f}, val_acc {:0.4f}'.format(tr_loss, tr_acc , val_loss, val_acc))
    history['epoch'].append(epoch+1)
    history['tr_loss'].append(round(tr_loss,5))
    history['tr_acc'].append(round(tr_acc,5))
    history['val_loss'].append(round(val_loss,5))
    history['val_acc'].append(round(val_acc,5))
# Out:
# Number of Training samples 2400, Batch Size 20, Num Batch 120
# [Epoch 1 of 200] Time elapsed 22.3s
# tr_loss: 0.6948,tr_acc 0.5150| val_loss 0.6717, val_acc 0.6125
# [Epoch 2 of 200] Time elapsed 21.2s
# tr_loss: 0.6746,tr_acc 0.5704| val_loss 0.6468, val_acc 0.6250
# [Epoch 3 of 200] Time elapsed 20.8s
# tr_loss: 0.6573,tr_acc 0.6154| val_loss 0.6176, val_acc 0.6863
# [Epoch 4 of 200] Time elapsed 21.0s
# tr_loss: 0.6355,tr_acc 0.6279| val_loss 0.6206, val_acc 0.6362
# [Epoch 5 of 200] Time elapsed 21.1s
# tr_loss: 0.5968,tr_acc 0.6792| val_loss 0.5289, val_acc 0.7125
# [Epoch 6 of 200] Time elapsed 21.0s
# tr_loss: 0.5568,tr_acc 0.7033| val_loss 0.4906, val_acc 0.7837
# [Epoch 7 of 200] Time elapsed 21.0s
# tr_loss: 0.5019,tr_acc 0.7408| val_loss 0.4754, val_acc 0.7600
# [Epoch 8 of 200] Time elapsed 20.9s
# tr_loss: 0.4794,tr_acc 0.7558| val_loss 0.4140, val_acc 0.8050
# [Epoch 9 of 200] Time elapsed 21.1s
# tr_loss: 0.4537,tr_acc 0.7771| val_loss 0.3853, val_acc 0.8400
# [Epoch 10 of 200] Time elapsed 21.7s
# tr_loss: 0.4354,tr_acc 0.7879| val_loss 0.3753, val_acc 0.8350
# [Epoch 11 of 200] Time elapsed 20.8s
# tr_loss: 0.4147,tr_acc 0.8125| val_loss 0.4371, val_acc 0.7900
# [Epoch 12 of 200] Time elapsed 20.9s
# tr_loss: 0.4014,tr_acc 0.8150| val_loss 0.3264, val_acc 0.8625
# [Epoch 13 of 200] Time elapsed 20.8s
# tr_loss: 0.3781,tr_acc 0.8287| val_loss 0.3626, val_acc 0.8375
# [Epoch 14 of 200] Time elapsed 20.9s
# tr_loss: 0.3748,tr_acc 0.8292| val_loss 0.3164, val_acc 0.8625
# [Epoch 15 of 200] Time elapsed 20.9s
# tr_loss: 0.3655,tr_acc 0.8354| val_loss 0.3186, val_acc 0.8600
# [Epoch 16 of 200] Time elapsed 21.1s
# tr_loss: 0.3515,tr_acc 0.8454| val_loss 0.3817, val_acc 0.8375
# [Epoch 17 of 200] Time elapsed 20.8s
# tr_loss: 0.3447,tr_acc 0.8446| val_loss 0.2902, val_acc 0.8762
# [Epoch 18 of 200] Time elapsed 20.8s
# tr_loss: 0.3240,tr_acc 0.8629| val_loss 0.3171, val_acc 0.8688
# [Epoch 19 of 200] Time elapsed 20.9s
# tr_loss: 0.3105,tr_acc 0.8621| val_loss 0.2770, val_acc 0.8788
# [Epoch 20 of 200] Time elapsed 20.8s
# tr_loss: 0.3062,tr_acc 0.8658| val_loss 0.3042, val_acc 0.8762
# [Epoch 21 of 200] Time elapsed 20.9s
# tr_loss: 0.3101,tr_acc 0.8658| val_loss 0.2324, val_acc 0.9075
# [Epoch 22 of 200] Time elapsed 20.7s
# tr_loss: 0.2943,tr_acc 0.8750| val_loss 0.2486, val_acc 0.9038
# [Epoch 23 of 200] Time elapsed 20.9s
# tr_loss: 0.2770,tr_acc 0.8788| val_loss 0.3797, val_acc 0.8400
# [Epoch 24 of 200] Time elapsed 21.4s
# tr_loss: 0.2790,tr_acc 0.8808| val_loss 0.2495, val_acc 0.9038
# [Epoch 25 of 200] Time elapsed 20.8s
# tr_loss: 0.2744,tr_acc 0.8733| val_loss 0.2986, val_acc 0.8725
# [Epoch 26 of 200] Time elapsed 20.8s
# tr_loss: 0.2585,tr_acc 0.8900| val_loss 0.2673, val_acc 0.8875
# [Epoch 27 of 200] Time elapsed 20.9s
# tr_loss: 0.2444,tr_acc 0.8946| val_loss 0.2370, val_acc 0.9000
# [Epoch 28 of 200] Time elapsed 20.8s
# tr_loss: 0.2456,tr_acc 0.8992| val_loss 0.2070, val_acc 0.9125
# [Epoch 29 of 200] Time elapsed 21.1s
# tr_loss: 0.2277,tr_acc 0.8967| val_loss 0.1913, val_acc 0.9325
# [Epoch 30 of 200] Time elapsed 21.2s
# tr_loss: 0.2236,tr_acc 0.9083| val_loss 0.1981, val_acc 0.9213
# [Epoch 31 of 200] Time elapsed 21.0s
# tr_loss: 0.2390,tr_acc 0.8958| val_loss 0.1825, val_acc 0.9275
# [Epoch 32 of 200] Time elapsed 20.8s
# tr_loss: 0.2228,tr_acc 0.9079| val_loss 0.1749, val_acc 0.9300
# [Epoch 33 of 200] Time elapsed 21.0s
# tr_loss: 0.2127,tr_acc 0.9117| val_loss 0.2140, val_acc 0.9163
# [Epoch 34 of 200] Time elapsed 21.0s
# tr_loss: 0.2085,tr_acc 0.9213| val_loss 0.2310, val_acc 0.9062
# [Epoch 35 of 200] Time elapsed 21.0s
# tr_loss: 0.1944,tr_acc 0.9175| val_loss 0.1676, val_acc 0.9413
# [Epoch 36 of 200] Time elapsed 20.9s
# tr_loss: 0.1994,tr_acc 0.9192| val_loss 0.1827, val_acc 0.9300
# [Epoch 37 of 200] Time elapsed 20.9s
# tr_loss: 0.1934,tr_acc 0.9142| val_loss 0.1784, val_acc 0.9337
# [Epoch 38 of 200] Time elapsed 20.9s
# tr_loss: 0.1927,tr_acc 0.9192| val_loss 0.1894, val_acc 0.9275
# [Epoch 39 of 200] Time elapsed 21.7s
# tr_loss: 0.1870,tr_acc 0.9175| val_loss 0.1795, val_acc 0.9275
# [Epoch 40 of 200] Time elapsed 21.1s
# tr_loss: 0.1816,tr_acc 0.9213| val_loss 0.2124, val_acc 0.9175
# [Epoch 41 of 200] Time elapsed 21.4s
# tr_loss: 0.1781,tr_acc 0.9325| val_loss 0.1815, val_acc 0.9300
# [Epoch 42 of 200] Time elapsed 21.1s
# tr_loss: 0.1693,tr_acc 0.9350| val_loss 0.1658, val_acc 0.9375
# [Epoch 43 of 200] Time elapsed 20.9s
# tr_loss: 0.1673,tr_acc 0.9346| val_loss 0.2094, val_acc 0.9250
# [Epoch 44 of 200] Time elapsed 21.4s
# tr_loss: 0.1634,tr_acc 0.9325| val_loss 0.1826, val_acc 0.9337
# [Epoch 45 of 200] Time elapsed 21.1s
# tr_loss: 0.1599,tr_acc 0.9379| val_loss 0.1983, val_acc 0.9287
# [Epoch 46 of 200] Time elapsed 21.0s
# tr_loss: 0.1520,tr_acc 0.9383| val_loss 0.2481, val_acc 0.9137
# [Epoch 47 of 200] Time elapsed 20.9s
# tr_loss: 0.1559,tr_acc 0.9337| val_loss 0.1575, val_acc 0.9413
# [Epoch 48 of 200] Time elapsed 21.0s
# tr_loss: 0.1517,tr_acc 0.9383| val_loss 0.1511, val_acc 0.9437
# [Epoch 49 of 200] Time elapsed 21.1s
# tr_loss: 0.1444,tr_acc 0.9408| val_loss 0.1697, val_acc 0.9425
# [Epoch 50 of 200] Time elapsed 21.1s
# tr_loss: 0.1501,tr_acc 0.9354| val_loss 0.1444, val_acc 0.9450
# [Epoch 51 of 200] Time elapsed 21.0s
# tr_loss: 0.1329,tr_acc 0.9446| val_loss 0.1848, val_acc 0.9350
# [Epoch 52 of 200] Time elapsed 21.0s
# tr_loss: 0.1224,tr_acc 0.9500| val_loss 0.1722, val_acc 0.9287
# [Epoch 53 of 200] Time elapsed 21.8s
# tr_loss: 0.1478,tr_acc 0.9387| val_loss 0.1526, val_acc 0.9475
# [Epoch 54 of 200] Time elapsed 20.8s
# tr_loss: 0.1175,tr_acc 0.9517| val_loss 0.2068, val_acc 0.9400
# [Epoch 55 of 200] Time elapsed 21.0s
# tr_loss: 0.1260,tr_acc 0.9479| val_loss 0.1670, val_acc 0.9450
# [Epoch 56 of 200] Time elapsed 21.1s
# tr_loss: 0.1240,tr_acc 0.9500| val_loss 0.2999, val_acc 0.9100
# [Epoch 57 of 200] Time elapsed 21.0s
# tr_loss: 0.1201,tr_acc 0.9554| val_loss 0.1536, val_acc 0.9475
# [Epoch 58 of 200] Time elapsed 21.0s
# tr_loss: 0.1228,tr_acc 0.9479| val_loss 0.4733, val_acc 0.8550
# [Epoch 59 of 200] Time elapsed 21.4s
# tr_loss: 0.1069,tr_acc 0.9571| val_loss 0.1580, val_acc 0.9425
# [Epoch 60 of 200] Time elapsed 21.1s
# tr_loss: 0.1208,tr_acc 0.9542| val_loss 0.1663, val_acc 0.9363
# [Epoch 61 of 200] Time elapsed 21.0s
# tr_loss: 0.1014,tr_acc 0.9613| val_loss 0.1303, val_acc 0.9513
# [Epoch 62 of 200] Time elapsed 21.1s
# tr_loss: 0.1082,tr_acc 0.9558| val_loss 0.5603, val_acc 0.8200
# [Epoch 63 of 200] Time elapsed 21.0s
# tr_loss: 0.1010,tr_acc 0.9583| val_loss 0.1430, val_acc 0.9537
# [Epoch 64 of 200] Time elapsed 21.0s
# tr_loss: 0.1130,tr_acc 0.9546| val_loss 0.1643, val_acc 0.9450
# [Epoch 65 of 200] Time elapsed 21.0s
# tr_loss: 0.0811,tr_acc 0.9683| val_loss 0.2698, val_acc 0.9125
# [Epoch 66 of 200] Time elapsed 21.0s
# tr_loss: 0.0960,tr_acc 0.9596| val_loss 0.1517, val_acc 0.9513
# [Epoch 67 of 200] Time elapsed 21.7s
# tr_loss: 0.0997,tr_acc 0.9637| val_loss 0.2086, val_acc 0.9313
# [Epoch 68 of 200] Time elapsed 21.2s
# tr_loss: 0.1053,tr_acc 0.9550| val_loss 0.1706, val_acc 0.9413
# [Epoch 69 of 200] Time elapsed 21.3s
# tr_loss: 0.0937,tr_acc 0.9587| val_loss 0.1689, val_acc 0.9400
# [Epoch 70 of 200] Time elapsed 21.0s
# tr_loss: 0.0949,tr_acc 0.9617| val_loss 0.1298, val_acc 0.9487
# [Epoch 71 of 200] Time elapsed 21.0s
# tr_loss: 0.0875,tr_acc 0.9608| val_loss 0.1424, val_acc 0.9587
# [Epoch 72 of 200] Time elapsed 21.0s
# tr_loss: 0.0839,tr_acc 0.9654| val_loss 0.1732, val_acc 0.9413
# [Epoch 73 of 200] Time elapsed 21.0s
# tr_loss: 0.0937,tr_acc 0.9613| val_loss 0.1917, val_acc 0.9325
# [Epoch 74 of 200] Time elapsed 21.3s
# tr_loss: 0.0840,tr_acc 0.9658| val_loss 0.1592, val_acc 0.9487
# [Epoch 75 of 200] Time elapsed 21.5s
# tr_loss: 0.0771,tr_acc 0.9696| val_loss 0.1533, val_acc 0.9475
# [Epoch 76 of 200] Time elapsed 21.0s
# tr_loss: 0.0813,tr_acc 0.9667| val_loss 0.2029, val_acc 0.9475
# [Epoch 77 of 200] Time elapsed 21.1s
# tr_loss: 0.0803,tr_acc 0.9688| val_loss 0.1648, val_acc 0.9587
# [Epoch 78 of 200] Time elapsed 21.1s
# tr_loss: 0.0890,tr_acc 0.9617| val_loss 0.2750, val_acc 0.9062
# [Epoch 79 of 200] Time elapsed 20.9s
# tr_loss: 0.0751,tr_acc 0.9717| val_loss 0.1676, val_acc 0.9513
# [Epoch 80 of 200] Time elapsed 21.0s
# tr_loss: 0.0815,tr_acc 0.9692| val_loss 0.1466, val_acc 0.9550
# [Epoch 81 of 200] Time elapsed 20.9s
# tr_loss: 0.0693,tr_acc 0.9750| val_loss 0.1647, val_acc 0.9513
# [Epoch 82 of 200] Time elapsed 21.6s
# tr_loss: 0.0708,tr_acc 0.9729| val_loss 0.1591, val_acc 0.9513
# [Epoch 83 of 200] Time elapsed 20.9s
# tr_loss: 0.0608,tr_acc 0.9754| val_loss 0.2080, val_acc 0.9450
# [Epoch 84 of 200] Time elapsed 20.9s
# tr_loss: 0.0700,tr_acc 0.9700| val_loss 0.1881, val_acc 0.9350
# [Epoch 85 of 200] Time elapsed 20.9s
# tr_loss: 0.0842,tr_acc 0.9650| val_loss 0.1399, val_acc 0.9575
# [Epoch 86 of 200] Time elapsed 21.0s
# tr_loss: 0.0605,tr_acc 0.9754| val_loss 0.1556, val_acc 0.9637
# [Epoch 87 of 200] Time elapsed 20.8s
# tr_loss: 0.0638,tr_acc 0.9717| val_loss 0.2042, val_acc 0.9500
# [Epoch 88 of 200] Time elapsed 21.0s
# tr_loss: 0.0687,tr_acc 0.9750| val_loss 0.1931, val_acc 0.9437
# [Epoch 89 of 200] Time elapsed 21.1s
# tr_loss: 0.0609,tr_acc 0.9746| val_loss 0.1825, val_acc 0.9450
# [Epoch 90 of 200] Time elapsed 21.0s
# tr_loss: 0.0612,tr_acc 0.9762| val_loss 0.1724, val_acc 0.9587
# [Epoch 91 of 200] Time elapsed 21.0s
# tr_loss: 0.0576,tr_acc 0.9775| val_loss 0.1924, val_acc 0.9487
# [Epoch 92 of 200] Time elapsed 21.0s
# tr_loss: 0.0665,tr_acc 0.9729| val_loss 0.1846, val_acc 0.9537
# [Epoch 93 of 200] Time elapsed 21.0s
# tr_loss: 0.0678,tr_acc 0.9738| val_loss 0.1590, val_acc 0.9613
# [Epoch 94 of 200] Time elapsed 20.9s
# tr_loss: 0.0664,tr_acc 0.9725| val_loss 0.1983, val_acc 0.9375
# [Epoch 95 of 200] Time elapsed 20.9s
# tr_loss: 0.0540,tr_acc 0.9783| val_loss 0.1808, val_acc 0.9450
# [Epoch 96 of 200] Time elapsed 21.7s
# tr_loss: 0.0636,tr_acc 0.9725| val_loss 0.1956, val_acc 0.9400
# [Epoch 97 of 200] Time elapsed 21.0s
# tr_loss: 0.0600,tr_acc 0.9746| val_loss 0.1524, val_acc 0.9600
# [Epoch 98 of 200] Time elapsed 21.0s
# tr_loss: 0.0497,tr_acc 0.9808| val_loss 0.1987, val_acc 0.9463
# [Epoch 99 of 200] Time elapsed 21.0s
# tr_loss: 0.0635,tr_acc 0.9767| val_loss 0.1777, val_acc 0.9513
# [Epoch 100 of 200] Time elapsed 20.9s
# tr_loss: 0.0575,tr_acc 0.9758| val_loss 0.1504, val_acc 0.9563
# [Epoch 101 of 200] Time elapsed 21.1s
# tr_loss: 0.0464,tr_acc 0.9821| val_loss 0.2291, val_acc 0.9250
# [Epoch 102 of 200] Time elapsed 20.9s
# tr_loss: 0.0556,tr_acc 0.9775| val_loss 0.1827, val_acc 0.9575
# [Epoch 103 of 200] Time elapsed 21.4s
# tr_loss: 0.0551,tr_acc 0.9812| val_loss 0.1793, val_acc 0.9575
# [Epoch 104 of 200] Time elapsed 21.0s
# tr_loss: 0.0591,tr_acc 0.9775| val_loss 0.1673, val_acc 0.9563
# [Epoch 105 of 200] Time elapsed 21.0s
# tr_loss: 0.0505,tr_acc 0.9817| val_loss 0.2027, val_acc 0.9587
# [Epoch 106 of 200] Time elapsed 20.9s
# tr_loss: 0.0453,tr_acc 0.9838| val_loss 0.2593, val_acc 0.9450
# [Epoch 107 of 200] Time elapsed 21.0s
# tr_loss: 0.0635,tr_acc 0.9750| val_loss 0.2179, val_acc 0.9463
# [Epoch 108 of 200] Time elapsed 20.9s
# tr_loss: 0.0439,tr_acc 0.9838| val_loss 0.1712, val_acc 0.9513
# [Epoch 109 of 200] Time elapsed 21.0s
# tr_loss: 0.0583,tr_acc 0.9771| val_loss 0.1855, val_acc 0.9575
# [Epoch 110 of 200] Time elapsed 21.1s
# tr_loss: 0.0406,tr_acc 0.9867| val_loss 0.1855, val_acc 0.9563
# [Epoch 111 of 200] Time elapsed 21.7s
# tr_loss: 0.0581,tr_acc 0.9817| val_loss 0.1700, val_acc 0.9563
# [Epoch 112 of 200] Time elapsed 20.9s
# tr_loss: 0.0417,tr_acc 0.9829| val_loss 0.1800, val_acc 0.9563
# [Epoch 113 of 200] Time elapsed 21.1s
# tr_loss: 0.0434,tr_acc 0.9842| val_loss 0.1635, val_acc 0.9575
# [Epoch 114 of 200] Time elapsed 21.0s
# tr_loss: 0.0578,tr_acc 0.9767| val_loss 0.1801, val_acc 0.9563
# [Epoch 115 of 200] Time elapsed 21.1s
# tr_loss: 0.0411,tr_acc 0.9858| val_loss 0.4043, val_acc 0.9200
# [Epoch 116 of 200] Time elapsed 21.0s
# tr_loss: 0.0376,tr_acc 0.9888| val_loss 0.1847, val_acc 0.9525
# [Epoch 117 of 200] Time elapsed 21.0s
# tr_loss: 0.0387,tr_acc 0.9858| val_loss 0.2220, val_acc 0.9463
# [Epoch 118 of 200] Time elapsed 21.3s
# tr_loss: 0.0434,tr_acc 0.9854| val_loss 0.2138, val_acc 0.9487
# [Epoch 119 of 200] Time elapsed 21.0s
# tr_loss: 0.0487,tr_acc 0.9800| val_loss 0.1719, val_acc 0.9563
# [Epoch 120 of 200] Time elapsed 21.0s
# tr_loss: 0.0449,tr_acc 0.9854| val_loss 0.1756, val_acc 0.9575
# [Epoch 121 of 200] Time elapsed 21.1s
# tr_loss: 0.0331,tr_acc 0.9871| val_loss 0.2414, val_acc 0.9463
# [Epoch 122 of 200] Time elapsed 21.3s
# tr_loss: 0.0688,tr_acc 0.9762| val_loss 0.1522, val_acc 0.9587
# [Epoch 123 of 200] Time elapsed 21.9s
# tr_loss: 0.0288,tr_acc 0.9883| val_loss 0.1793, val_acc 0.9563
# [Epoch 124 of 200] Time elapsed 22.3s
# tr_loss: 0.0354,tr_acc 0.9875| val_loss 0.1874, val_acc 0.9563
# [Epoch 125 of 200] Time elapsed 22.5s
# tr_loss: 0.0495,tr_acc 0.9838| val_loss 0.2056, val_acc 0.9563
# [Epoch 126 of 200] Time elapsed 21.0s
# tr_loss: 0.0366,tr_acc 0.9850| val_loss 0.1619, val_acc 0.9625
# [Epoch 127 of 200] Time elapsed 20.9s
# tr_loss: 0.0365,tr_acc 0.9842| val_loss 0.2272, val_acc 0.9487
# [Epoch 128 of 200] Time elapsed 20.9s
# tr_loss: 0.0362,tr_acc 0.9867| val_loss 0.1946, val_acc 0.9587
# [Epoch 129 of 200] Time elapsed 21.0s
# tr_loss: 0.0435,tr_acc 0.9838| val_loss 0.2665, val_acc 0.9413
# [Epoch 130 of 200] Time elapsed 21.1s
# tr_loss: 0.0354,tr_acc 0.9862| val_loss 0.2281, val_acc 0.9537
# [Epoch 131 of 200] Time elapsed 21.0s
# tr_loss: 0.0330,tr_acc 0.9879| val_loss 0.2420, val_acc 0.9475
# [Epoch 132 of 200] Time elapsed 21.3s
# tr_loss: 0.0374,tr_acc 0.9862| val_loss 0.2285, val_acc 0.9463
# [Epoch 133 of 200] Time elapsed 21.0s
# tr_loss: 0.0346,tr_acc 0.9862| val_loss 0.1287, val_acc 0.9613
# [Epoch 134 of 200] Time elapsed 20.9s
# tr_loss: 0.0450,tr_acc 0.9842| val_loss 0.1895, val_acc 0.9613
# [Epoch 135 of 200] Time elapsed 20.9s
# tr_loss: 0.0449,tr_acc 0.9800| val_loss 0.1783, val_acc 0.9563
# [Epoch 136 of 200] Time elapsed 20.8s
# tr_loss: 0.0243,tr_acc 0.9908| val_loss 0.1962, val_acc 0.9525
# [Epoch 137 of 200] Time elapsed 20.8s
# tr_loss: 0.0319,tr_acc 0.9892| val_loss 0.2221, val_acc 0.9437
# [Epoch 138 of 200] Time elapsed 20.8s
# tr_loss: 0.0287,tr_acc 0.9900| val_loss 0.6384, val_acc 0.8950
# [Epoch 139 of 200] Time elapsed 21.5s
# tr_loss: 0.0531,tr_acc 0.9812| val_loss 0.5404, val_acc 0.8950
# [Epoch 140 of 200] Time elapsed 21.1s
# tr_loss: 0.0289,tr_acc 0.9875| val_loss 0.1523, val_acc 0.9613
# [Epoch 141 of 200] Time elapsed 21.0s
# tr_loss: 0.0372,tr_acc 0.9871| val_loss 0.1540, val_acc 0.9575
# [Epoch 142 of 200] Time elapsed 21.1s
# tr_loss: 0.0254,tr_acc 0.9908| val_loss 0.1949, val_acc 0.9537
# [Epoch 143 of 200] Time elapsed 20.9s
# tr_loss: 0.0440,tr_acc 0.9858| val_loss 0.1758, val_acc 0.9550
# [Epoch 144 of 200] Time elapsed 21.0s
# tr_loss: 0.0228,tr_acc 0.9904| val_loss 0.2030, val_acc 0.9500
# [Epoch 145 of 200] Time elapsed 21.2s
# tr_loss: 0.0240,tr_acc 0.9921| val_loss 0.1916, val_acc 0.9600
# [Epoch 146 of 200] Time elapsed 20.9s
# tr_loss: 0.0397,tr_acc 0.9854| val_loss 0.1894, val_acc 0.9613
# [Epoch 147 of 200] Time elapsed 21.2s
# tr_loss: 0.0378,tr_acc 0.9862| val_loss 0.1923, val_acc 0.9587
# [Epoch 148 of 200] Time elapsed 20.9s
# tr_loss: 0.0177,tr_acc 0.9921| val_loss 0.2302, val_acc 0.9500
# [Epoch 149 of 200] Time elapsed 20.9s
# tr_loss: 0.0300,tr_acc 0.9912| val_loss 0.1880, val_acc 0.9587
# [Epoch 150 of 200] Time elapsed 20.7s
# tr_loss: 0.0338,tr_acc 0.9900| val_loss 0.3143, val_acc 0.9450
# [Epoch 151 of 200] Time elapsed 20.9s
# tr_loss: 0.0287,tr_acc 0.9904| val_loss 0.1962, val_acc 0.9600
# [Epoch 152 of 200] Time elapsed 20.8s
# tr_loss: 0.0286,tr_acc 0.9875| val_loss 0.2015, val_acc 0.9563
# [Epoch 153 of 200] Time elapsed 20.7s
# tr_loss: 0.0442,tr_acc 0.9862| val_loss 0.1795, val_acc 0.9600
# [Epoch 154 of 200] Time elapsed 22.0s
# tr_loss: 0.0317,tr_acc 0.9879| val_loss 0.2773, val_acc 0.9537
# [Epoch 155 of 200] Time elapsed 20.8s
# tr_loss: 0.0310,tr_acc 0.9888| val_loss 0.2282, val_acc 0.9550
# [Epoch 156 of 200] Time elapsed 20.7s
# tr_loss: 0.0271,tr_acc 0.9912| val_loss 0.1980, val_acc 0.9550
# [Epoch 157 of 200] Time elapsed 20.8s
# tr_loss: 0.0183,tr_acc 0.9925| val_loss 0.2079, val_acc 0.9513
# [Epoch 158 of 200] Time elapsed 21.2s
# tr_loss: 0.0257,tr_acc 0.9896| val_loss 0.2598, val_acc 0.9537
# [Epoch 159 of 200] Time elapsed 20.8s
# tr_loss: 0.0332,tr_acc 0.9888| val_loss 0.2029, val_acc 0.9637
# [Epoch 160 of 200] Time elapsed 20.9s
# tr_loss: 0.0308,tr_acc 0.9917| val_loss 0.2158, val_acc 0.9600
# [Epoch 161 of 200] Time elapsed 20.9s
# tr_loss: 0.0172,tr_acc 0.9946| val_loss 0.2073, val_acc 0.9537
# [Epoch 162 of 200] Time elapsed 21.1s
# tr_loss: 0.0300,tr_acc 0.9875| val_loss 0.1884, val_acc 0.9487
# [Epoch 163 of 200] Time elapsed 20.8s
# tr_loss: 0.0270,tr_acc 0.9912| val_loss 0.1836, val_acc 0.9600
# [Epoch 164 of 200] Time elapsed 20.9s
# tr_loss: 0.0306,tr_acc 0.9892| val_loss 0.2317, val_acc 0.9487
# [Epoch 165 of 200] Time elapsed 20.8s
# tr_loss: 0.0241,tr_acc 0.9908| val_loss 0.2082, val_acc 0.9500
# [Epoch 166 of 200] Time elapsed 20.7s
# tr_loss: 0.0210,tr_acc 0.9929| val_loss 0.2585, val_acc 0.9475
# [Epoch 167 of 200] Time elapsed 20.7s
# tr_loss: 0.0238,tr_acc 0.9929| val_loss 0.2400, val_acc 0.9487
# [Epoch 168 of 200] Time elapsed 21.4s
# tr_loss: 0.0346,tr_acc 0.9875| val_loss 0.3200, val_acc 0.9437
# [Epoch 169 of 200] Time elapsed 20.9s
# tr_loss: 0.0276,tr_acc 0.9900| val_loss 0.2112, val_acc 0.9563
# [Epoch 170 of 200] Time elapsed 20.8s
# tr_loss: 0.0326,tr_acc 0.9883| val_loss 0.3271, val_acc 0.9350
# [Epoch 171 of 200] Time elapsed 20.8s
# tr_loss: 0.0248,tr_acc 0.9900| val_loss 0.2447, val_acc 0.9500
# [Epoch 172 of 200] Time elapsed 20.8s
# tr_loss: 0.0246,tr_acc 0.9888| val_loss 0.1801, val_acc 0.9600
# [Epoch 173 of 200] Time elapsed 20.7s
# tr_loss: 0.0145,tr_acc 0.9954| val_loss 0.1830, val_acc 0.9625
# [Epoch 174 of 200] Time elapsed 20.8s
# tr_loss: 0.0246,tr_acc 0.9904| val_loss 0.2562, val_acc 0.9525
# [Epoch 175 of 200] Time elapsed 21.0s
# tr_loss: 0.0268,tr_acc 0.9879| val_loss 0.1949, val_acc 0.9600
# [Epoch 176 of 200] Time elapsed 21.0s
# tr_loss: 0.0240,tr_acc 0.9925| val_loss 0.2463, val_acc 0.9563
# [Epoch 177 of 200] Time elapsed 21.1s
# tr_loss: 0.0342,tr_acc 0.9892| val_loss 0.2012, val_acc 0.9575
# [Epoch 178 of 200] Time elapsed 20.8s
# tr_loss: 0.0287,tr_acc 0.9925| val_loss 0.2169, val_acc 0.9550
# [Epoch 179 of 200] Time elapsed 20.8s
# tr_loss: 0.0252,tr_acc 0.9933| val_loss 0.2451, val_acc 0.9563
# [Epoch 180 of 200] Time elapsed 20.8s
# tr_loss: 0.0220,tr_acc 0.9925| val_loss 0.2073, val_acc 0.9613
# [Epoch 181 of 200] Time elapsed 21.0s
# tr_loss: 0.0277,tr_acc 0.9892| val_loss 0.2562, val_acc 0.9513
# [Epoch 182 of 200] Time elapsed 21.0s
# tr_loss: 0.0154,tr_acc 0.9942| val_loss 0.2265, val_acc 0.9550
# [Epoch 183 of 200] Time elapsed 21.7s
# tr_loss: 0.0175,tr_acc 0.9929| val_loss 0.2524, val_acc 0.9475
# [Epoch 184 of 200] Time elapsed 21.1s
# tr_loss: 0.0303,tr_acc 0.9900| val_loss 0.2547, val_acc 0.9550
# [Epoch 185 of 200] Time elapsed 20.8s
# tr_loss: 0.0203,tr_acc 0.9929| val_loss 0.2612, val_acc 0.9563
# [Epoch 186 of 200] Time elapsed 20.9s
# tr_loss: 0.0190,tr_acc 0.9929| val_loss 0.2706, val_acc 0.9563
# [Epoch 187 of 200] Time elapsed 20.8s
# tr_loss: 0.0321,tr_acc 0.9896| val_loss 0.2062, val_acc 0.9525
# [Epoch 188 of 200] Time elapsed 20.9s
# tr_loss: 0.0112,tr_acc 0.9971| val_loss 0.4408, val_acc 0.9337
# [Epoch 189 of 200] Time elapsed 20.9s
# tr_loss: 0.0293,tr_acc 0.9896| val_loss 0.2537, val_acc 0.9525
# [Epoch 190 of 200] Time elapsed 21.0s
# tr_loss: 0.0204,tr_acc 0.9933| val_loss 0.2438, val_acc 0.9425
# [Epoch 191 of 200] Time elapsed 21.1s
# tr_loss: 0.0169,tr_acc 0.9962| val_loss 0.1978, val_acc 0.9537
# [Epoch 192 of 200] Time elapsed 21.3s
# tr_loss: 0.0174,tr_acc 0.9938| val_loss 0.3039, val_acc 0.9513
# [Epoch 193 of 200] Time elapsed 20.9s
# tr_loss: 0.0230,tr_acc 0.9921| val_loss 0.2373, val_acc 0.9563
# [Epoch 194 of 200] Time elapsed 20.9s
# tr_loss: 0.0187,tr_acc 0.9933| val_loss 0.2011, val_acc 0.9600
# [Epoch 195 of 200] Time elapsed 20.9s
# tr_loss: 0.0233,tr_acc 0.9908| val_loss 0.2067, val_acc 0.9575
# [Epoch 196 of 200] Time elapsed 20.9s
# tr_loss: 0.0302,tr_acc 0.9908| val_loss 0.2194, val_acc 0.9587
# [Epoch 197 of 200] Time elapsed 21.4s
# tr_loss: 0.0173,tr_acc 0.9942| val_loss 0.1421, val_acc 0.9625
# [Epoch 198 of 200] Time elapsed 20.9s
# tr_loss: 0.0322,tr_acc 0.9892| val_loss 0.2222, val_acc 0.9563
# [Epoch 199 of 200] Time elapsed 20.9s
# tr_loss: 0.0209,tr_acc 0.9917| val_loss 0.2230, val_acc 0.9463
# [Epoch 200 of 200] Time elapsed 20.9s
# tr_loss: 0.0172,tr_acc 0.9933| val_loss 0.2269, val_acc 0.9575
# CPU times: user 4min 3s, sys: 3min 23s, total: 7min 27s
# Wall time: 1h 10min 7s

# %% [markdown]
# ## Plot Training vs Validation results[](http://)

# %%
plot_results(history)
best_epoch = get_best_epcoh(history)
# Out:
# Best Validation Accuracy Score 0.96375, is for epoch 86
